# %%
import pandas as pd
from google.colab import files

# %%
files.upload()
data=pd.read_csv(r"combinenew.csv"),
data
# Out:
#      <input type="file" id="files-7e0e3e89-d1e4-45ee-99f5-c3f1bd0bf64b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e0e3e89-d1e4-45ee-99f5-c3f1bd0bf64b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0    Destination Port             5001 non-null   int64
#  1    Flow Duration                5001 non-null   int64
#  2    Total Fwd Packets            5001 non-null   int64
#  3    Total Backward Packets       5000 non-null   float64
#  4   Total Length of Fwd Packets   5000 non-null   float64
#  5    Total Length of Bwd Packets  5000 non-null   float64
#  6    Fwd Packet Length Max        5001 non-null   int64
#  7    Fwd Packet Length Min        5000 non-null   float64
#  8    Fwd Packet Length Mean       5001 non-null   float64
#  9    Fwd Packet Length Std        5001 non-null   float64
#  10  Bwd Packet Length Max         5001 non-null   int64
#  11   Bwd Packet Length Min        5000 non-null   float64
# ...

# %%
df = pd.DataFrame(data[0])

# %%
df
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
# 4999                 53             172                   2
# 5000                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
data[0].isnull()
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 False           False               False
# 1                 False           False               False
# 2                 False           False               False
# 3                 False           False               False
# 4                 False           False               False
# ...                 ...             ...                 ...
# 4996              False           False               False
# 4997              False           False               False
# 4998              False           False               False
# 4999              False           False               False
# 5000              False           False               False
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# ...

# %%
df.isnull().sum()
# Out:
#  Destination Port              0
#  Flow Duration                 0
#  Total Fwd Packets             0
#  Total Backward Packets        1
# Total Length of Fwd Packets    1
#                               ..
# Idle Mean                      0
#  Idle Std                      0
#  Idle Max                      0
#  Idle Min                      0
#  Label                         0
# Length: 79, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df.drop_duplicates()
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
# 4999                 53             172                   2
# 5000                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count        5001.000000    5.001000e+03         5001.000000
# mean         6627.596481    1.106466e+07            8.405119
# std         16930.792390    2.962087e+07           27.653351
# min             0.000000    0.000000e+00            1.000000
# 25%            53.000000    2.400000e+02            2.000000
# 50%            80.000000    4.930100e+04            2.000000
# 75%           443.000000    5.026300e+05            7.000000
# max         60966.000000    1.199947e+08         1611.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count              5000.000000                  5000.000000
# mean                  8.869800                   980.440400
# std                  34.637448                  6562.203436
# min                   0.000000                     0.000000
# 25%                   1.000000                    43.000000
# ...

# %%
df.dropna()
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
avg = df[' Active Max']

# %%
avg
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4994    0
# 4995    0
# 4996    0
# 4997    0
# 4998    0
# Name:  Active Max, Length: 4973, dtype: int64

# %%
df.fillna(avg)
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df[' Active Max'].fillna(avg,inplace=True)
# Out:
# /tmp/ipython-input-1838884293.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[' Active Max'].fillna(avg,inplace=True)

# %%
df
# Out:
#        Destination Port   Flow Duration   Total Fwd Packets  \
# 0                 54865               3                   2
# 1                 55054             109                   1
# 2                 55055              52                   1
# 3                 46236              34                   1
# 4                 54863               3                   2
# ...                 ...             ...                 ...
# 4994                 53          111898                   2
# 4995                 53             202                   2
# 4996                 53           47443                   2
# 4997                 53             173                   2
# 4998                 53             152                   2
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 0                         0.0                         12.0
# 1                         1.0                          6.0
# 2                         1.0                          6.0
# ...

# %%
df[' Flow Duration'].fillna(df[' Flow Duration'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-1041369931.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[' Flow Duration'].fillna(df[' Flow Duration'].mean(),inplace=True)

# %%
df[' Active Max'].fillna(0,inplace=True)
# Out:
# /tmp/ipython-input-2485795394.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[' Active Max'].fillna(0,inplace=True)

# %%
df.to_csv("updated.csv",index =False)

# %%
files.download("updated.csv")

# %%
import matplotlib.pyplot as plt

# %%
# The original code had an AttributeError: 'DataFrame' object has no attribute 'group'.
# The correct method for grouping dataframes is .groupby().
# Also, the column 'size_of_data' does not exist in the dataframe 'df'.
# I've commented out the 'def_url' line as its purpose is unclear in relation to the scatter plot and it would still lead to an error due to the missing 'size_of_data' column.

# def_url=df.groupby('size_of_data')['Flow Duration']

# Using 'Total Length of Fwd Packets' as a placeholder for 'size_of_data'.
# Please replace 'Total Length of Fwd Packets' with the correct column name if it's different.
plt.scatter(df['Total Length of Fwd Packets'], df[' Flow Duration'])
plt.xlabel("Total Length of Fwd Packets") # Updated label to reflect the chosen column
plt.ylabel("Flow Duration")
plt.show()
